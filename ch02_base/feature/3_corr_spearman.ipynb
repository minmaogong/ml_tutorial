# %%
# 斯皮尔曼相关系数（Spearman's rank correlation coefficient）是一种非参数统计方法，用于衡量两个变量之间的单调关系。与皮尔逊相关系数不同，斯皮尔曼相关系数不要求数据满足正态分布，也不要求线性关系。它通过将数据转换为排名来计算相关性，因此适用于处理非线性关系和异常值。

# %%
import pandas as pd

# %%
# 每周学习时长
X = [[5], [8], [10], [12], [15], [3], [7], [9], [14], [6]]
# 数学考试成绩
y = [55, 65, 70, 75, 85, 50, 60, 72, 80, 58]

# %%
X = pd.DataFrame(X)
y = pd.Series(y)
print(X)
print(y)
# Out:
#     0
# 0   5
# 1   8
# 2  10
# 3  12
# 4  15
# 5   3
# 6   7
# 7   9
# 8  14
# 9   6
# 0    55
# 1    65
# 2    70
# 3    75
# 4    85
# 5    50
# 6    60
# 7    72
# 8    80
# 9    58
# dtype: int64

# %%
# 计算斯皮尔曼相关系数
corr = X.corrwith(y, method='spearman') # corrwith 计算每个特征与标签之间的相关系数 method='spearman' 使用斯皮尔曼相关系数
print(corr)
# Out:
# 0    0.987879
# dtype: float64
