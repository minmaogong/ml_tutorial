# %% [markdown]
# # KNN 算法 - 分类任务

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
# 1. 准备数据
X = [[2, 1], [3, 1], [1, 4], [2, 6]] # 特征
y = [0, 0, 1, 1] # 标签

# %%
# 2. 定义模型：KNN分类器实例对象，设置邻居数为2
knn = KNeighborsClassifier(n_neighbors=2, weights='distance') # weights='distance' 表示根据距离加权，距离近的点权重更大

# %%
# 3. 训练模型
knn.fit(X, y) # fit 训练模型，X 是特征数据，y 是标签数据
# Out:
# KNeighborsClassifier(n_neighbors=2, weights='distance')

# %%
# 4. 预测新数据的类别
x = [[4, 9]]
x_class = knn.predict(x)
print(x_class)
# Out:
# [1]

# %% [markdown]
# # 画图

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# 转成ndarray
X = np.array(X)
y = np.array(y)
print(X.shape)
print(y.shape)
# Out:
# (4, 2)
# (4,)

# %%
# 按类别将点分为两组
X1 = X[y==0]
X2 = X[y==1]
print(X1)
print(X2)
# Out:
# [[2 1]
#  [3 1]]
# [[1 4]
#  [2 6]]

# %%
fig, ax = plt.subplots()
ax.axis('equal')

colors = ['C0', 'C1']
plt.scatter(X1[:, 0], X1[:, 1], c=colors[0])
plt.scatter(X2[:, 0], X2[:, 1], c=colors[1])

x_color = colors[0] if x_class[0] == 0 else colors[1]
plt.scatter(x[0][0], x[0][1], c=x_color)
plt.show()
